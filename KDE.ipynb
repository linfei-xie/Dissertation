# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fire = pd.read_csv('LFB.csv')

# %%
fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27192 entries, 0 to 27191
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   IncidentNumber                          27192 non-null  int64
#  1   DateOfCall                              27192 non-null  object
#  2   CalYear                                 27192 non-null  int64
#  3   TimeOfCall                              27192 non-null  object
#  4   HourOfCall                              27192 non-null  int64
#  5   IncidentGroup                           27192 non-null  object
#  6   StopCodeDescription                     27192 non-null  object
#  7   SpecialServiceType                      0 non-null      float64
#  8   PropertyCategory                        27192 non-null  object
#  9   PropertyType                            27192 non-null  object
# ...

# %%
sns.jointplot(x="Easting_rounded", y="Northing_rounded", data=fire);

# %%
sns.kdeplot(fire['Easting_rounded'], fire['Northing_rounded'], shade=True, cmap='viridis');
# Out:
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
london = gpd.read_file('london.shp')

# %%
f, ax = plt.subplots(1, figsize=(8, 8))



sns.kdeplot(fire['Easting_rounded'], fire['Northing_rounded'], \
            shade=True, cmap='Purples', \
            ax=ax);

london.plot(color='none',edgecolor='black',linewidth=0.1, ax=ax)


plt.axis('equal')
# Out:
# /opt/conda/envs/sds2020/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
